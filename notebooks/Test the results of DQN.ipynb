# %%
import numpy as np
import csv
import json
import matplotlib.pyplot as plt

# %%
fileName = '../results/agentDQN.csv'

# %%
with open(fileName) as f:
    reader = csv.reader(f)
    for l in reader:
        t, specs, scores, sumScores = l
        specs = json.loads(specs)
        scores = json.loads(scores)
        sumScores = json.loads(sumScores)
        decay, lr, tau = specs['epsDecay'], specs['lr'], specs['Tau']
        print(f'{decay}, {lr:.2e},  {tau:.2e}, {np.max(scores):6.2f}, {np.max(sumScores):6.2f}')
        
plt.figure(figsize=(10, 10))
ax1 = plt.axes([0, 0, 0.5, 1])
ax2 = plt.axes([0.5, 0, 0.5, 1])
with open(fileName) as f:
    reader = csv.reader(f)
    for i, l in enumerate(reader):
        t, specs, scores, sumScores = l
        specs = json.loads(specs)
        scores = json.loads(scores)
        sumScores = json.loads(sumScores)
        decay, lr = specs['epsDecay'], specs['lr']
        ax1.plot(np.array(scores)+5*i)
        ax1.axhline(5*i, color='k')
        ax2.plot(np.array(sumScores)+2*i)
        ax2.axhline(2*i, color='k')
plt.show()
# Out:
# 0.999, 1.00e-05,  1.00e-03,   7.00,   0.69
# 0.999, 2.78e-05,  1.00e-03,   5.00,   0.38
# 0.999, 7.74e-05,  1.00e-03,   2.00,   0.10
# 0.999, 2.15e-04,  1.00e-03,   7.00,   0.30
# 0.999, 5.99e-04,  1.00e-03,   6.00,   0.00
# 0.999, 1.67e-03,  1.00e-03,   3.00,   1.00
# 0.999, 1.29e-02,  1.00e-03,   3.00,   0.06
# 0.999, 3.59e-02,  1.00e-03,   6.00,   3.00
# 0.999, 1.00e-01,  1.00e-03,   2.00,   0.25
# 0.988, 1.00e-05,  1.00e-03,   6.00,   0.38
# 0.988, 2.78e-05,  1.00e-03,   2.00,   0.50
# 0.988, 7.74e-05,  1.00e-03,   4.00,   0.23
# 0.988, 2.15e-04,  1.00e-03,   5.00,   2.00
# 0.988, 5.99e-04,  1.00e-03,   4.00,   2.00
# 0.988, 1.67e-03,  1.00e-03,   8.00,   0.38
# 0.988, 4.64e-03,  1.00e-03,   4.00,   0.50
# 0.988, 1.29e-02,  1.00e-03,   3.00,   0.60
# 0.988, 3.59e-02,  1.00e-03,   8.00,   2.50
# 0.988, 1.00e-01,  1.00e-03,   2.00,  -0.04

# %%
import six
